# %% [markdown]
# <a href="https://colab.research.google.com/github/yakupusame/HousePrice/blob/master/HousePrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
test
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
#test['SalePrice'] = 'NA'

# %%
test
# Out:
#         Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0     1461          20       RH  ...    2010        WD        Normal
# 1     1462          20       RL  ...    2010        WD        Normal
# 2     1463          60       RL  ...    2010        WD        Normal
# 3     1464          60       RL  ...    2010        WD        Normal
# 4     1465         120       RL  ...    2010        WD        Normal
# ...    ...         ...      ...  ...     ...       ...           ...
# 1454  2915         160       RM  ...    2006        WD        Normal
# 1455  2916         160       RM  ...    2006        WD       Abnorml
# 1456  2917          20       RL  ...    2006        WD       Abnorml
# 1457  2918          85       RL  ...    2006        WD        Normal
# 1458  2919          60       RL  ...    2006        WD        Normal
#
# [1459 rows x 80 columns]

# %%
train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
#train['istest'] = 0

# %%
#train

# %%
#test['istest'] = 1

# %%
#test

# %%
#df  = np.concatenate([train,test])

# %%
#df = pd.DataFrame(df)

# %%
#df

# %%
#df.describe

# %%
test.describe()
# Out:
#                 Id   MSSubClass  ...       MoSold       YrSold
# count  1459.000000  1459.000000  ...  1459.000000  1459.000000
# mean   2190.000000    57.378341  ...     6.104181  2007.769705
# std     421.321334    42.746880  ...     2.722432     1.301740
# min    1461.000000    20.000000  ...     1.000000  2006.000000
# 25%    1825.500000    20.000000  ...     4.000000  2007.000000
# 50%    2190.000000    50.000000  ...     6.000000  2008.000000
# 75%    2554.500000    70.000000  ...     8.000000  2009.000000
# max    2919.000000   190.000000  ...    12.000000  2010.000000
#
# [8 rows x 37 columns]

# %%
train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %%
train_cat = train[['MSSubClass' , 'MSZoning' , 'Street','Alley','LotShape', 'LandContour', 'Utilities', 'LotConfig','LandSlope','Neighborhood','Condition1','Condition2',
                  'BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','MasVnrArea','ExterQual',
                  'ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinSF1','BsmtFinType2',
                  'Heating','CentralAir','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageArea',
                  'GarageQual','GarageCond','PavedDrive','PoolQC','Fence','MiscFeature','SaleType','SaleCondition','BsmtFullBath','BsmtHalfBath',
                   'FullBath','HalfBath']]

# %%
np.unique(train['PoolArea'])
# Out:
# array([  0, 480, 512, 519, 555, 576, 648, 738])

# %%
train_num = train[['LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtUnfSF','TotalBsmtSF',
              '1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BedroomAbvGr','KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageYrBlt',
              'GarageCars','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MoSold',
              'YrSold']]

# %%
train_num
# Out:
#       LotFrontage  LotArea  OverallQual  ...  PoolArea  MoSold  YrSold
# 0            65.0     8450            7  ...         0       2    2008
# 1            80.0     9600            6  ...         0       5    2007
# 2            68.0    11250            7  ...         0       9    2008
# 3            60.0     9550            7  ...         0       2    2006
# 4            84.0    14260            8  ...         0      12    2008
# ...           ...      ...          ...  ...       ...     ...     ...
# 1455         62.0     7917            6  ...         0       8    2007
# 1456         85.0    13175            6  ...         0       2    2010
# 1457         66.0     9042            7  ...         0       5    2010
# 1458         68.0     9717            5  ...         0       4    2010
# 1459         75.0     9937            5  ...         0       6    2008
#
# [1460 rows x 29 columns]

# %%
train.hist( bins = 30 , figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fec333dd828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec3332fac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec33360d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec33310f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec332cc240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec3327d4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fec3322d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec3325d940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec3325d9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec331c3e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec331820f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec33134358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fec331685c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec3311b828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec330cda90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec33081cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec33036f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32ff7208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fec33029470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32fdd6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32f8f940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32f43ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32ef6e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32eb70b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fec32e6c320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32e9d588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32e517f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec33377ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec3326a5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec331294a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fec32f9dc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32e63358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32cf8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32cac6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32cde940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32c92ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fec32c49e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32c070b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32bba320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32b6c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32ba07f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fec32b52a58>]],
#       dtype=object)

# %%
train_corr = train.corr()['SalePrice']
train_corr
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# LotFrontage      0.351799
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.486362
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# MoSold           0.046432
# YrSold          -0.028923
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
pd.set_option('display.max_rows', None)
print(train.isnull().sum().sort_values(ascending = False))
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
# LotConfig           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BldgType            0
# Condition2          0
# BsmtFinSF1          0
# MSZoning            0
# LotArea             0
# Street              0
# Condition1          0
# Neighborhood        0
# LotShape            0
# LandContour         0
# LandSlope           0
# SalePrice           0
# HeatingQC           0
# BsmtFinSF2          0
# EnclosedPorch       0
# Fireplaces          0
# GarageCars          0
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# 3SsnPorch           0
# BsmtUnfSF           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# Functional          0
# TotRmsAbvGrd        0
# KitchenQual         0
# KitchenAbvGr        0
# BedroomAbvGr        0
# HalfBath            0
# FullBath            0
# BsmtHalfBath        0
# BsmtFullBath        0
# GrLivArea           0
# LowQualFinSF        0
# 2ndFlrSF            0
# 1stFlrSF            0
# CentralAir          0
# SaleCondition       0
# Heating             0
# TotalBsmtSF         0
# Id                  0
# dtype: int64

# %%
train['PoolQC'].shape
# Out:
# (1460,)

# %%
train.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %%
var = 'GrLivArea'

data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
#scatterplot
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(train[cols], size = 2.5)
plt.show();
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
pd.concat()
